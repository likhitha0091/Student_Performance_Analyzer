# %%
import pandas as pd

data = {
    "Name": ["Asha", "Rahul", "Meena", "Kiran", "Sita"],
    "Math": [78, 45, 92, 60, 35],
    "Physics": [85, 52, 88, 58, 40],
    "CS": [90, 60, 95, 65, 42]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Math  Physics  CS
# 0   Asha    78       85  90
# 1  Rahul    45       52  60
# 2  Meena    92       88  95
# 3  Kiran    60       58  65
# 4   Sita    35       40  42
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Math'].plot(kind='hist', bins=20, title='Math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Physics'].plot(kind='hist', bins=20, title='Physics')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['CS'].plot(kind='hist', bins=20, title='CS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Math     5 non-null      int64
#  2   Physics  5 non-null      int64
#  3   CS       5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
df["Average"] = df[["Math", "Physics", "CS"]].mean(axis=1)

# %%
df
# Out:
#     Name  Math  Physics  CS    Average
# 0   Asha    78       85  90  84.333333
# 1  Rahul    45       52  60  52.333333
# 2  Meena    92       88  95  91.666667
# 3  Kiran    60       58  65  61.000000
# 4   Sita    35       40  42  39.000000

# %%
def assign_grade(avg):
    if avg >= 85:
        return "A"
    elif avg >= 70:
        return "B"
    elif avg >= 50:
        return "C"
    elif avg >= 35:
        return "D"
    else:
        return "F"

# %%
df["Grade"] = df["Average"].apply(assign_grade)
df
# Out:
#     Name  Math  Physics  CS    Average Grade
# 0   Asha    78       85  90  84.333333     B
# 1  Rahul    45       52  60  52.333333     C
# 2  Meena    92       88  95  91.666667     A
# 3  Kiran    60       58  65  61.000000     C
# 4   Sita    35       40  42  39.000000     D

# %%
df["Result"] = df["Grade"].apply(lambda x: "Fail" if x == "F" else "Pass")
df
# Out:
#     Name  Math  Physics  CS    Average Grade Result
# 0   Asha    78       85  90  84.333333     B   Pass
# 1  Rahul    45       52  60  52.333333     C   Pass
# 2  Meena    92       88  95  91.666667     A   Pass
# 3  Kiran    60       58  65  61.000000     C   Pass
# 4   Sita    35       40  42  39.000000     D   Pass

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(df["Name"], df["Average"])
plt.xlabel("Students")
plt.ylabel("Average Marks")
plt.title("Average Marks of Students")
plt.show()

# %%
grade_counts = df["Grade"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(grade_counts, labels=grade_counts.index, autopct="%1.1f%%")
plt.title("Grade Distribution")
plt.show()

# %%
df.to_csv("student_performance_results.csv", index=False)

# %%
plt.figure(figsize=(8, 5))
plt.bar(df["Name"], df["Average"])
plt.xlabel("Students")
plt.ylabel("Average Marks")
plt.title("Average Marks of Students")
plt.savefig("average_marks.png")
plt.show()

# %%
grade_counts = df["Grade"].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(grade_counts, labels=grade_counts.index, autopct="%1.1f%%")
plt.title("Grade Distribution")
plt.savefig("grade_distribution.png")
plt.show()
